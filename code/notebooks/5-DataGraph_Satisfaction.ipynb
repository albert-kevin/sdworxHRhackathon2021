# %% [markdown]
# Author: Kevin ALBERT
#
# Created: Feb 2021

# %%
from py2neo import Graph, Node, Relationship
import pandas as pd
from IPython.display import Javascript
from fuzzywuzzy import process, fuzz

# %%
import platform
import psutil
import os

# %%
conda_version = ! conda -V
print(f"conda : {conda_version[0].split()[1]}")
pip_version = ! pip -V
print(f"pip   : {pip_version[0].split()[1]}")
python_version = ! python -V
print(f"python: {python_version[0].split()[1]}")
pandas_version = ! pip list |grep -i pandas
print(f"pandas: {pandas_version[0].split()[1]}")
py2neo_version = ! pip list |grep -i py2neo
print(f"py2neo: {py2neo_version[0].split()[1]}")
# Out:
# conda : 4.9.2
# pip   : 21.0.1
# python: 3.8.6
# pandas: 1.2.1
# py2neo: 4.2.0

# %%
server  = "168.63.44.210"
port    = "7687"
user    = "neo4j"
passw   = "digityser"
db_name = "neo4j"        # default name (v4.x)

# %%
# load graph connection instance
graph = Graph(host=server, auth=(user, passw), name=db_name, encrypted=False)

# %% [markdown]
# ## prepare data
# We may be trying to do it for all 3 dataset groups !

# %%
# import the datasets
synthetic_df = pd.read_parquet("../../data/silver/synthetic_data_processed.parquet")
entities_df = pd.read_parquet("../../data/bronze/entities_What_Should_We_Do_To_Make_You_Feel_Better_And_Increase_Your_Overall_Satisfaction.parquet")
sentiment_df = pd.read_parquet("../../data/bronze/sentiment_What_Should_We_Do_To_Make_You_Feel_Better_And_Increase_Your_Overall_Satisfaction.parquet")
keyphrase_df = pd.read_parquet("../../data/bronze/key_phrases_What_Should_We_Do_To_Make_You_Feel_Better_And_Increase_Your_Overall_Satisfaction.parquet")

# %%
# creating unique patient ID
synthetic_df["id"] = synthetic_df.index

# %%
# replace nan
synthetic_df['What_Felt_Best_During_This_Last_Month'] = synthetic_df['What_Felt_Best_During_This_Last_Month'].fillna('No Feeling')
synthetic_df['What_Should_We_Do_To_Make_You_Feel_Better_And_Increase_Your_Overall_Satisfaction'] = synthetic_df['What_Should_We_Do_To_Make_You_Feel_Better_And_Increase_Your_Overall_Satisfaction'].fillna('No Satisfaction')
synthetic_df['Any_Additional_Suggestion_To_Improve'] = synthetic_df['Any_Additional_Suggestion_To_Improve'].fillna('No Improvement')

# %%
synthetic_df
# Out:
#                                   email full_name  \
# 0             Lorem.ipsum@congueelit.ca  Harrison
# 1   elit.elit.fermentum@Crasinterdum.ca   Clinton
# 2                         semper@mi.com     Scott
# 3            tellus.non@velsapien.co.uk   Russell
# 4              vitae@nisinibhlacinia.ca      Kane
# ..                                  ...       ...
# 95     erat.vel@egestasrhoncusProin.edu    Victor
# 96                     In@vitaeorci.net    Gareth
# 97               elementum@necurnaet.ca     Avram
# 98      quis.pede.Suspendisse@risus.edu      Coby
# 99           enim@ridiculusmusProin.org    Hector
#
#     how_was_your_last_month_in_your_assignment  \
# 0                                            4
# 1                                            4
# 2                                            3
# 3                                            1
# 4                                            4
# ..                                         ...
# 95                                           4
# 96                                           2
# 97                                           4
# 98                                           4
# 99                                           4
#
#     How_Was_Your_Last_Month_Within_Your_Department  \
# 0                                                4
# 1                                                4
# 2                                                3
# 3                                                1
# 4                                                4
# ..                                             ...
# 95                                               4
# 96                                               2
# 97                                               4
# 98                                               4
# 99                                               4
#
#     How_Was_Your_Last_Month_With_Us  \
# 0                                 4
# 1                                 4
# 2                                 2
# 3                                 1
# 4                                 3
# ..                              ...
# 95                                2
# 96                                1
# 97                                4
# 98                                4
# 99                                2
#
#                 What_Felt_Best_During_This_Last_Month  \
# 0   collaborating closely with Damien,  closing th...
# 1                                      being promoted
# 2                     team building we had last month
# 3                                     not much for me
# 4    getting to work with you guys is a real pleasure
# ..                                                ...
# 95                                         No Feeling
# 96                                         No Feeling
# 97                                         No Feeling
# 98                                         No Feeling
# 99                                         No Feeling
#
#    What_Should_We_Do_To_Make_You_Feel_Better_And_Increase_Your_Overall_Satisfaction  \
# 0   keep the good vibes, the trust and open commun...
# 1                     maintain the good collaboration
# 2   more consideration for the employes, making th...
# 3   I don't feel that my skills and capacities are...
# 4                               less micro management
# ..                                                ...
# 95                                    No Satisfaction
# 96                                    No Satisfaction
# 97                                    No Satisfaction
# 98                                    No Satisfaction
# 99                                    No Satisfaction
#
#                  Any_Additional_Suggestion_To_Improve  \
# 0         more sync between the different departments
# 1                             keep up the good energy
# 2                 Don’t be friends during work hours.
# 3                If a few managers took a chill pill.
# 4   I would like to talk to the managers just to s...
# ..                                                ...
# 95                                     No Improvement
# 96                                     No Improvement
# 97                                     No Improvement
# 98                                     No Improvement
# 99                                     No Improvement
#
#     any_additional_comments  I_Would_Like_To_Get_Called_By  \
# 0                       NaN                            NaN
# 1                       NaN                            NaN
# 2                       NaN                            NaN
# 3                       NaN                            NaN
# 4                       NaN                            NaN
# ..                      ...                            ...
# 95                      NaN                            NaN
# 96                      NaN                            NaN
# 97                      NaN                            NaN
# 98                      NaN                            NaN
# 99                      NaN                            NaN
#
#     I_Would_Like_To_Provide_A_Copy_Of_My_Answers_To  id
# 0                                               NaN   0
# 1                                               NaN   1
# 2                                               NaN   2
# 3                                               NaN   3
# 4                                               NaN   4
# ..                                              ...  ..
# 95                                              NaN  95
# 96                                              NaN  96
# 97                                              NaN  97
# 98                                              NaN  98
# 99                                              NaN  99
#
# [100 rows x 12 columns]

# %%
# count missing values, sorted (high missing > 5%)
synthetic_df.isnull().apply(lambda x: x.sum() * 100 / len(synthetic_df)).round(1).sort_values(ascending=True)
# Out:
# email                                                                                 0.0
# full_name                                                                             0.0
# how_was_your_last_month_in_your_assignment                                            0.0
# How_Was_Your_Last_Month_Within_Your_Department                                        0.0
# How_Was_Your_Last_Month_With_Us                                                       0.0
# What_Felt_Best_During_This_Last_Month                                                 0.0
# What_Should_We_Do_To_Make_You_Feel_Better_And_Increase_Your_Overall_Satisfaction      0.0
# Any_Additional_Suggestion_To_Improve                                                  0.0
# id                                                                                    0.0
# any_additional_comments                                                             100.0
# I_Would_Like_To_Get_Called_By                                                       100.0
# I_Would_Like_To_Provide_A_Copy_Of_My_Answers_To                                     100.0
# dtype: float64

# %%
# save file to database /import
file_synthetic = "synthetic_data_processed.csv"
synthetic_df.to_csv("../../neo4j/import/"+file_synthetic, sep=',', index=False)

file_entities3 = "entities3.csv"
entities_df.to_csv("../../neo4j/import/"+file_entities3, sep=',', index=False)

file_sentiment3 = "sentiment3.csv"
sentiment_df.to_csv("../../neo4j/import/"+file_sentiment3, sep=',', index=False)

file_keyphrase3 = "keyphrases3.csv"
keyphrase_df.to_csv("../../neo4j/import/"+file_keyphrase3, sep=',', index=False)

# %% [markdown]
# ## import data in DB
#
# [link to arrows data modeling tool](https://arrows.app/#/import/json=...)

# %% [markdown]
# #### cognitive data

# %%
entities_df
# Out:
#                                              document  \
# 0   keep the good vibes, the trust and open commun...
# 1                     maintain the good collaboration
# 2   more consideration for the employes, making th...
# 3                               less micro management
# 4                      valuate all staff the same way
# 5   more transparency about the financial situatio...
# 6   making the employees in the heart of managemen...
# 7                      more openness and transparency
# 8                                       more training
# 9    offer more opportunities for continuous learning
# 10                  put more energy in  our CSR work
# 11                  put more energy in  our CSR work
# 12  so far I've been pleased pleased for the help ...
# 13  I asked for help because the work load becomes...
# 14  we should put more energy in collecting feedba...
# 15  we should put more energy in collecting feedba...
# 16  I would love to feel more implicated in the de...
# 17  I would love to feel more implicated in the de...
# 18      give us the opportunity to have a real impact
# 19  with my new certification I would like to join...
# 20  with my new certification I would like to join...
#
#                                              entities          entity_text  \
# 0   {'text': 'communication', 'category': 'Skill',...        communication
# 1   {'text': 'collaboration', 'category': 'Skill',...        collaboration
# 2   {'text': 'management decision', 'category': 'S...  management decision
# 3   {'text': 'micro management', 'category': 'Skil...     micro management
# 4   {'text': 'valuate', 'category': 'Skill', 'subc...              valuate
# 5   {'text': 'financial', 'category': 'Skill', 'su...            financial
# 6   {'text': 'management', 'category': 'Skill', 's...           management
# 7   {'text': 'openness', 'category': 'Skill', 'sub...             openness
# 8   {'text': 'training', 'category': 'Skill', 'sub...             training
# 9   {'text': 'continuous learning', 'category': 'S...  continuous learning
# 10  {'text': 'energy', 'category': 'Skill', 'subca...               energy
# 11  {'text': 'CSR', 'category': 'Skill', 'subcateg...                  CSR
# 12  {'text': 'onboarding', 'category': 'Skill', 's...           onboarding
# 13  {'text': 'until now', 'category': 'DateTime', ...            until now
# 14  {'text': 'energy', 'category': 'Skill', 'subca...               energy
# 15  {'text': 'collecting', 'category': 'Skill', 's...           collecting
# 16  {'text': 'impact', 'category': 'Skill', 'subca...               impact
# 17  {'text': 'my day', 'category': 'DateTime', 'su...               my day
# 18  {'text': 'impact', 'category': 'Skill', 'subca...               impact
# 19  {'text': 'certification', 'category': 'Skill',...        certification
# 20  {'text': 'scrum', 'category': 'Skill', 'subcat...                scrum
#
#    entity_category entity_subcategory  entity_confidence_score
# 0            Skill               None                      0.8
# 1            Skill               None                      0.8
# 2            Skill               None                      0.8
# 3            Skill               None                      0.8
# 4            Skill               None                      0.8
# 5            Skill               None                      0.8
# 6            Skill               None                      0.8
# 7            Skill               None                      0.8
# 8            Skill               None                      0.8
# 9            Skill               None                      0.8
# 10           Skill               None                      0.8
# 11           Skill               None                      0.8
# 12           Skill               None                      0.8
# 13        DateTime      DateTimeRange                      0.8
# 14           Skill               None                      0.8
# 15           Skill               None                      0.8
# 16           Skill               None                      0.8
# 17        DateTime               Date                      0.8
# 18           Skill               None                      0.8
# 19           Skill               None                      0.8
# 20           Skill               None                      0.8

# %%
# count missing values, sorted (high missing > 5%)
entities_df.isnull().apply(lambda x: x.sum() * 100 / len(entities_df)).round(1).sort_values(ascending=True)
# Out:
# document                   0.0
# entities                   0.0
# entity_text                0.0
# entity_category            0.0
# entity_subcategory         0.0
# entity_confidence_score    0.0
# dtype: float64

# %% [markdown]
# #### replace Suggestion Node to either Feeling, Satisfaction or Suggestion into the other 2 notebooks!!
# here it must be Satisfaction

# %%
query = """
USING PERIODIC COMMIT 1000
LOAD CSV WITH HEADERS FROM 'file:///"""+file_entities3+"""' AS line FIELDTERMINATOR ','
WITH line WHERE line.entity_category = 'Event'
MATCH (satisfaction:Satisfaction {description:(line.document)})
MERGE (event:Event {value:(line.entity_text)})
MERGE (event)-[:EVENT_IN]->(satisfaction)
"""
display(graph.run(query).stats())
query = """
USING PERIODIC COMMIT 1000
LOAD CSV WITH HEADERS FROM 'file:///"""+file_entities3+"""' AS line FIELDTERMINATOR ','
WITH line WHERE line.entity_category = 'Location'
MATCH (satisfaction:Satisfaction {description:(line.document)})
MERGE (location:Location {value:(line.entity_text)})
MERGE (location)-[:LOCATION_IN]->(satisfaction)
"""
display(graph.run(query).stats())
query = """
USING PERIODIC COMMIT 1000
LOAD CSV WITH HEADERS FROM 'file:///"""+file_entities3+"""' AS line FIELDTERMINATOR ','
WITH line WHERE line.entity_category = 'Product'
MATCH (satisfaction:Satisfaction {description:(line.document)})
MERGE (product:Product {value:(line.entity_text)})
MERGE (product)-[:PRODUCT_IN]->(satisfaction)
"""
display(graph.run(query).stats())
query = """
USING PERIODIC COMMIT 1000
LOAD CSV WITH HEADERS FROM 'file:///"""+file_entities3+"""' AS line FIELDTERMINATOR ','
WITH line WHERE line.entity_category = 'Skill'
MATCH (satisfaction:Satisfaction {description:(line.document)})
MERGE (skill:Skill {value:(line.entity_text)})
MERGE (skill)-[:SKILL_IN]->(satisfaction)
"""
display(graph.run(query).stats())
query = """
USING PERIODIC COMMIT 1000
LOAD CSV WITH HEADERS FROM 'file:///"""+file_entities3+"""' AS line FIELDTERMINATOR ','
WITH line WHERE line.entity_category = 'Quantity'
MATCH (satisfaction:Satisfaction {description:(line.document)})
MERGE (quantity:Quantity {value:(line.entity_text)})
MERGE (quantity)-[:QUANTITY_IN]->(satisfaction)
"""
display(graph.run(query).stats())
query = """
USING PERIODIC COMMIT 1000
LOAD CSV WITH HEADERS FROM 'file:///"""+file_entities3+"""' AS line FIELDTERMINATOR ','
WITH line WHERE line.entity_category = 'PersonType'
MATCH (satisfaction:Satisfaction {description:(line.document)})
MERGE (persontype:PersonType {value:(line.entity_text)})
MERGE (persontype)-[:PERSONTYPE_IN]->(satisfaction)
"""
display(graph.run(query).stats())
# Out:
# constraints_added: 0
# constraints_removed: 0
# contains_updates: False
# indexes_added: 0
# indexes_removed: 0
# labels_added: 0
# labels_removed: 0
# nodes_created: 0
# nodes_deleted: 0
# properties_set: 0
# relationships_created: 0
# relationships_deleted: 0
# constraints_added: 0
# constraints_removed: 0
# contains_updates: False
# indexes_added: 0
# indexes_removed: 0
# labels_added: 0
# labels_removed: 0
# nodes_created: 0
# nodes_deleted: 0
# properties_set: 0
# relationships_created: 0
# relationships_deleted: 0
# constraints_added: 0
# constraints_removed: 0
# contains_updates: False
# indexes_added: 0
# indexes_removed: 0
# labels_added: 0
# labels_removed: 0
# nodes_created: 0
# nodes_deleted: 0
# properties_set: 0
# relationships_created: 0
# relationships_deleted: 0
# constraints_added: 0
# constraints_removed: 0
# contains_updates: True
# indexes_added: 0
# indexes_removed: 0
# labels_added: 14
# labels_removed: 0
# nodes_created: 14
# nodes_deleted: 0
# properties_set: 14
# relationships_created: 19
# relationships_deleted: 0
# constraints_added: 0
# constraints_removed: 0
# contains_updates: False
# indexes_added: 0
# indexes_removed: 0
# labels_added: 0
# labels_removed: 0
# nodes_created: 0
# nodes_deleted: 0
# properties_set: 0
# relationships_created: 0
# relationships_deleted: 0
# constraints_added: 0
# constraints_removed: 0
# contains_updates: False
# indexes_added: 0
# indexes_removed: 0
# labels_added: 0
# labels_removed: 0
# nodes_created: 0
# nodes_deleted: 0
# properties_set: 0
# relationships_created: 0
# relationships_deleted: 0

# %% [markdown]
# #### sentiment

# %%
sentiment_df
# Out:
#                                              document sentiment
# 0   keep the good vibes, the trust and open commun...  positive
# 1                     maintain the good collaboration  positive
# 2   more consideration for the employes, making th...   neutral
# 3   I don't feel that my skills and capacities are...  negative
# 4                               less micro management   neutral
# ..                                                ...       ...
# 95                                               none   neutral
# 96                                               none   neutral
# 97                                               none   neutral
# 98                                               none   neutral
# 99                                               none   neutral
#
# [100 rows x 2 columns]

# %%
query = """
USING PERIODIC COMMIT 1000
LOAD CSV WITH HEADERS FROM 'file:///"""+file_sentiment3+"""' AS line FIELDTERMINATOR ','
MATCH (satisfaction:Satisfaction {description:(line.document)})
MERGE (sentiment:Sentiment {value:(line.sentiment)})
MERGE (sentiment)-[:SENTIMENT_IN]->(satisfaction)
"""
display(graph.run(query).stats())
# Out:
# constraints_added: 0
# constraints_removed: 0
# contains_updates: True
# indexes_added: 0
# indexes_removed: 0
# labels_added: 0
# labels_removed: 0
# nodes_created: 0
# nodes_deleted: 0
# properties_set: 0
# relationships_created: 37
# relationships_deleted: 0

# %% [markdown]
# ## Querying

# %% [markdown]
# ## reset DB

# %%
# delete database and restart (wait ~2min)
import os
os.system(" cd ../.. && \
            sudo docker-compose down && \
            sudo rm -Rf neo4j/data/databases/neo4j && \
            sudo rm -Rf neo4j/data/transactions/neo4j && \
            sudo docker-compose up --build &")
