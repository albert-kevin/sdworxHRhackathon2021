# %% [markdown]
# Author: Kevin ALBERT
#
# Created: Feb 2021

# %%
# !pip install pyarrow fastparquet

# %%
# current python SDK versions:
# !pip freeze | grep azure-ai-textanalytics
# Out:
# azure-ai-textanalytics==5.0.0

# %% [markdown]
# Generated API keys and endpoints

# %%
azure_textanalytics_key = '2180035c81284813a4d457640c87f017'
azure_textanalytics_endpoint = 'https://westeurope.api.cognitive.microsoft.com/'
azure_textanalytics_url = azure_textanalytics_endpoint + 'text/analytics/v3.0'

# %%
import warnings
warnings.filterwarnings("ignore")
import os
import requests
import json
import time
import uuid
import glob
from io import BytesIO
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as patches
# %matplotlib inline

# %%
from azure.ai.textanalytics import TextAnalyticsClient         # for text analytics
from azure.core.credentials import AzureKeyCredential          # for text analytics

# %% [markdown]
# API docs: https://westeurope.dev.cognitive.microsoft.com/docs/services/TextAnalytics-v3-0/operations/Languages

# %%
client = TextAnalyticsClient(azure_textanalytics_endpoint, AzureKeyCredential(azure_textanalytics_key))

# %% [markdown]
# ## key_phrases

# %%
# documents = ["My cat might need to see a veterinarian."]
documents = ["I had a wonderful trip to Seattle last week.",
             "This was a waste of my time. The speaker put me to sleep.",
             "I don't feel that my skills and capacities are taking into account."]

# %%
keyphrases_response = client.extract_key_phrases(documents)
[i.__dict__ for i in keyphrases_response]

# %%
for idx, doc in enumerate(keyphrases_response):
    print(idx, doc)

# %%
# showing the last line, this is a list
doc.key_phrases

# %% [markdown]
# ## sentiment

# %%
# documents = ["Dit is een heel mooie show.",
#              "This was a waste of my time. The speaker put me to sleep."]
documents = ["I had a wonderful trip to Seattle last week.",
             "This was a waste of my time. The speaker put me to sleep.",
             "I don't feel that my skills and capacities are taking into account."]

# %%
sentiment_response = client.analyze_sentiment(documents)
[i.__dict__ for i in sentiment_response]

# %%
for idx, doc in enumerate(sentiment_response):
    print(idx, doc)

# %%
doc.sentiment

# %%
doc.sentences[0]

# %% [markdown]
# ## named_entities

# %%
documents = ["I had a wonderful trip to Seattle last week.",
             "This was a waste of my time. The speaker put me to sleep.",
             "I don't feel that my skills and capacities are taking into account."]

# %%
response = client.recognize_entities(documents)
[i.__dict__ for i in response]

# %% [markdown]
# save to *.csv

# %% [markdown]
# ## load data
#
# We need to run this for 3 columns ! (repeat this process 3x)
#  1. Any_Additional_Suggestion_To_Improve
#  1. What_Felt_Best_During_This_Last_Month
#  1. What_Should_We_Do_To_Make_You_Feel_Better_And_Increase_Your_Overall_Satisfaction
#
# don't forget to remove null values, remove old csv files and rename the final datasets

# %%
synthetic_df = pd.read_csv("../../data/bronze/sdworxHRhackathon2021.csv")

# %%
synthetic_df.head(2).T
# Out:
#                                                                                                     0  \
# email                                                                       Lorem.ipsum@congueelit.ca
# full_name                                                                                    Harrison
# how_was_your_last_month_in_your_assignment                                                          4
# How_Was_Your_Last_Month_Within_Your_Department                                                      4
# How_Was_Your_Last_Month_With_Us                                                                     4
# What_Felt_Best_During_This_Last_Month               collaborating closely with Damien,  closing th...
# What_Should_We_Do_To_Make_You_Feel_Better_And_I...  keep the good vibes, the trust and open commun...
# Any_Additional_Suggestion_To_Improve                      more sync between the different departments
# any_additional_comments                                                                           NaN
# I_Would_Like_To_Get_Called_By                                                                     NaN
# I_Would_Like_To_Provide_A_Copy_Of_My_Answers_To                                                   NaN
#
#                                                                                       1
# email                                               elit.elit.fermentum@Crasinterdum.ca
# full_name                                                                       Clinton
# how_was_your_last_month_in_your_assignment                                            4
# How_Was_Your_Last_Month_Within_Your_Department                                        4
# How_Was_Your_Last_Month_With_Us                                                       4
# What_Felt_Best_During_This_Last_Month                                    being promoted
# What_Should_We_Do_To_Make_You_Feel_Better_And_I...      maintain the good collaboration
# Any_Additional_Suggestion_To_Improve                            keep up the good energy
# any_additional_comments                                                             NaN
# I_Would_Like_To_Get_Called_By                                                       NaN
# I_Would_Like_To_Provide_A_Copy_Of_My_Answers_To                                     NaN

# %%
# here you replace the columns 3x as well:
df = pd.DataFrame({'col1': synthetic_df["What_Should_We_Do_To_Make_You_Feel_Better_And_Increase_Your_Overall_Satisfaction"].values})
# replace nan
df['col1'] = df['col1'].fillna('none')
df
# Out:
#                                                  col1
# 0   keep the good vibes, the trust and open commun...
# 1                     maintain the good collaboration
# 2   more consideration for the employes, making th...
# 3   I don't feel that my skills and capacities are...
# 4                               less micro management
# ..                                                ...
# 95                                               none
# 96                                               none
# 97                                               none
# 98                                               none
# 99                                               none
#
# [100 rows x 1 columns]

# %% [markdown]
# #### generating entities

# %%
# replace 'key' and 'endpoint':
azure_textanalytics_key = '2180035c81284813a4d457640c87f017'
azure_textanalytics_endpoint = 'https://westeurope.api.cognitive.microsoft.com/'

import pandas as pd
from azure.core.credentials import AzureKeyCredential
from azure.ai.textanalytics import TextAnalyticsClient
client = TextAnalyticsClient(azure_textanalytics_endpoint, AzureKeyCredential(azure_textanalytics_key))

result = pd.DataFrame()
temp   = []
start  = 0      # index id start (ex: 0)
stop   = 100   # index id stop  (ex: 5000)
step   = 1      # max 5 (ex: 5)
column = "col1" # from dataframe
# https://docs.microsoft.com/en-us/azure/cognitive-services/text-analytics/concepts/data-limits

for i in range(start, stop, step): # 0-5000, 5000-10000, etc... (~10min)
    documents = (df[column].iloc[i:i+step]).tolist()
    response = client.recognize_entities(documents)
    print(i, end='\r') # counter
    for idx, doc in enumerate(response):
        comment = pd.DataFrame()
        for idy, entity in enumerate(doc.entities):
            comment.loc[idy, "document"] = str(documents[idx])
            comment.loc[idy, "entities"] = str(entity)
            comment.loc[idy, "entity_text"] = str(entity.text)
            comment.loc[idy, "entity_category"] = str(entity.category)
            comment.loc[idy, "entity_subcategory"] = str(entity.subcategory)
            comment.loc[idy, "entity_confidence_score"] = str(entity.confidence_score)
        temp.append(comment)
        
result = pd.concat(temp, axis=0, ignore_index=True)
result.to_csv("entities_"+str(start)+"_"+str(stop)+".csv", index=False)
result
# Out:
# 99
#                                              document  \
# 0   keep the good vibes, the trust and open commun...
# 1                     maintain the good collaboration
# 2   more consideration for the employes, making th...
# 3                               less micro management
# 4                      valuate all staff the same way
# 5   more transparency about the financial situatio...
# 6   making the employees in the heart of managemen...
# 7                      more openness and transparency
# 8                                       more training
# 9    offer more opportunities for continuous learning
# 10                  put more energy in  our CSR work
# 11                  put more energy in  our CSR work
# 12  so far I've been pleased pleased for the help ...
# 13  I asked for help because the work load becomes...
# 14  we should put more energy in collecting feedba...
# 15  we should put more energy in collecting feedba...
# 16  I would love to feel more implicated in the de...
# 17  I would love to feel more implicated in the de...
# 18      give us the opportunity to have a real impact
# 19  with my new certification I would like to join...
# 20  with my new certification I would like to join...
#
#                                              entities          entity_text  \
# 0   {'text': 'communication', 'category': 'Skill',...        communication
# 1   {'text': 'collaboration', 'category': 'Skill',...        collaboration
# 2   {'text': 'management decision', 'category': 'S...  management decision
# 3   {'text': 'micro management', 'category': 'Skil...     micro management
# 4   {'text': 'valuate', 'category': 'Skill', 'subc...              valuate
# 5   {'text': 'financial', 'category': 'Skill', 'su...            financial
# 6   {'text': 'management', 'category': 'Skill', 's...           management
# 7   {'text': 'openness', 'category': 'Skill', 'sub...             openness
# 8   {'text': 'training', 'category': 'Skill', 'sub...             training
# 9   {'text': 'continuous learning', 'category': 'S...  continuous learning
# 10  {'text': 'energy', 'category': 'Skill', 'subca...               energy
# 11  {'text': 'CSR', 'category': 'Skill', 'subcateg...                  CSR
# 12  {'text': 'onboarding', 'category': 'Skill', 's...           onboarding
# 13  {'text': 'until now', 'category': 'DateTime', ...            until now
# 14  {'text': 'energy', 'category': 'Skill', 'subca...               energy
# 15  {'text': 'collecting', 'category': 'Skill', 's...           collecting
# 16  {'text': 'impact', 'category': 'Skill', 'subca...               impact
# 17  {'text': 'my day', 'category': 'DateTime', 'su...               my day
# 18  {'text': 'impact', 'category': 'Skill', 'subca...               impact
# 19  {'text': 'certification', 'category': 'Skill',...        certification
# 20  {'text': 'scrum', 'category': 'Skill', 'subcat...                scrum
#
#    entity_category entity_subcategory entity_confidence_score
# 0            Skill               None                     0.8
# 1            Skill               None                     0.8
# 2            Skill               None                     0.8
# 3            Skill               None                     0.8
# 4            Skill               None                     0.8
# 5            Skill               None                     0.8
# 6            Skill               None                     0.8
# 7            Skill               None                     0.8
# 8            Skill               None                     0.8
# 9            Skill               None                     0.8
# 10           Skill               None                     0.8
# 11           Skill               None                     0.8
# 12           Skill               None                     0.8
# 13        DateTime      DateTimeRange                     0.8
# 14           Skill               None                     0.8
# 15           Skill               None                     0.8
# 16           Skill               None                     0.8
# 17        DateTime               Date                     0.8
# 18           Skill               None                     0.8
# 19           Skill               None                     0.8
# 20           Skill               None                     0.8

# %%
# Merge it all together into one csv
import glob

all_files = glob.glob("entities_*.csv")
li = []
for filename in all_files:
    dataset = pd.read_csv(filename)
    li.append(dataset)
result = pd.concat(li, axis=0, ignore_index=True)
result.to_parquet("../../data/bronze/entities_What_Should_We_Do_To_Make_You_Feel_Better_And_Increase_Your_Overall_Satisfaction.parquet")
result
# Out:
#                                              document  \
# 0   keep the good vibes, the trust and open commun...
# 1                     maintain the good collaboration
# 2   more consideration for the employes, making th...
# 3                               less micro management
# 4                      valuate all staff the same way
# 5   more transparency about the financial situatio...
# 6   making the employees in the heart of managemen...
# 7                      more openness and transparency
# 8                                       more training
# 9    offer more opportunities for continuous learning
# 10                  put more energy in  our CSR work
# 11                  put more energy in  our CSR work
# 12  so far I've been pleased pleased for the help ...
# 13  I asked for help because the work load becomes...
# 14  we should put more energy in collecting feedba...
# 15  we should put more energy in collecting feedba...
# 16  I would love to feel more implicated in the de...
# 17  I would love to feel more implicated in the de...
# 18      give us the opportunity to have a real impact
# 19  with my new certification I would like to join...
# 20  with my new certification I would like to join...
#
#                                              entities          entity_text  \
# 0   {'text': 'communication', 'category': 'Skill',...        communication
# 1   {'text': 'collaboration', 'category': 'Skill',...        collaboration
# 2   {'text': 'management decision', 'category': 'S...  management decision
# 3   {'text': 'micro management', 'category': 'Skil...     micro management
# 4   {'text': 'valuate', 'category': 'Skill', 'subc...              valuate
# 5   {'text': 'financial', 'category': 'Skill', 'su...            financial
# 6   {'text': 'management', 'category': 'Skill', 's...           management
# 7   {'text': 'openness', 'category': 'Skill', 'sub...             openness
# 8   {'text': 'training', 'category': 'Skill', 'sub...             training
# 9   {'text': 'continuous learning', 'category': 'S...  continuous learning
# 10  {'text': 'energy', 'category': 'Skill', 'subca...               energy
# 11  {'text': 'CSR', 'category': 'Skill', 'subcateg...                  CSR
# 12  {'text': 'onboarding', 'category': 'Skill', 's...           onboarding
# 13  {'text': 'until now', 'category': 'DateTime', ...            until now
# 14  {'text': 'energy', 'category': 'Skill', 'subca...               energy
# 15  {'text': 'collecting', 'category': 'Skill', 's...           collecting
# 16  {'text': 'impact', 'category': 'Skill', 'subca...               impact
# 17  {'text': 'my day', 'category': 'DateTime', 'su...               my day
# 18  {'text': 'impact', 'category': 'Skill', 'subca...               impact
# 19  {'text': 'certification', 'category': 'Skill',...        certification
# 20  {'text': 'scrum', 'category': 'Skill', 'subcat...                scrum
#
#    entity_category entity_subcategory  entity_confidence_score
# 0            Skill               None                      0.8
# 1            Skill               None                      0.8
# 2            Skill               None                      0.8
# 3            Skill               None                      0.8
# 4            Skill               None                      0.8
# 5            Skill               None                      0.8
# 6            Skill               None                      0.8
# 7            Skill               None                      0.8
# 8            Skill               None                      0.8
# 9            Skill               None                      0.8
# 10           Skill               None                      0.8
# 11           Skill               None                      0.8
# 12           Skill               None                      0.8
# 13        DateTime      DateTimeRange                      0.8
# 14           Skill               None                      0.8
# 15           Skill               None                      0.8
# 16           Skill               None                      0.8
# 17        DateTime               Date                      0.8
# 18           Skill               None                      0.8
# 19           Skill               None                      0.8
# 20           Skill               None                      0.8

# %% [markdown]
# #### generating sentiment

# %%
# replace 'key' and 'endpoint':
azure_textanalytics_key = '2180035c81284813a4d457640c87f017'
azure_textanalytics_endpoint = 'https://westeurope.api.cognitive.microsoft.com/'

import pandas as pd
from azure.core.credentials import AzureKeyCredential
from azure.ai.textanalytics import TextAnalyticsClient
client = TextAnalyticsClient(azure_textanalytics_endpoint, AzureKeyCredential(azure_textanalytics_key))

result = pd.DataFrame()
temp   = []
start  = 0      # index id start (ex: 0)
stop   = 100   # index id stop  (ex: 5000)
step   = 1      # max 5 (ex: 5)
column = "col1" # from dataframe
# https://docs.microsoft.com/en-us/azure/cognitive-services/text-analytics/concepts/data-limits

for i in range(start, stop, step): # 0-5000, 5000-10000, etc... (~10min)
    documents = (df[column].iloc[i:i+step]).tolist()

    sentiment_response = client.analyze_sentiment(documents)
    print(i, end='\r') # second counter
    for idx, doc in enumerate(sentiment_response):
        comment = pd.DataFrame()
        comment.loc[idy, "document"] = str(documents[idx])
        comment.loc[idy, "sentiment"] = str(doc.sentiment)
    temp.append(comment)

result = pd.concat(temp, axis=0, ignore_index=True)
result.to_csv("sentiment_"+str(start)+"_"+str(stop)+".csv", index=False)
result
# Out:
# 99
#                                              document sentiment
# 0   keep the good vibes, the trust and open commun...  positive
# 1                     maintain the good collaboration  positive
# 2   more consideration for the employes, making th...   neutral
# 3   I don't feel that my skills and capacities are...  negative
# 4                               less micro management   neutral
# ..                                                ...       ...
# 95                                               none   neutral
# 96                                               none   neutral
# 97                                               none   neutral
# 98                                               none   neutral
# 99                                               none   neutral
#
# [100 rows x 2 columns]

# %%
# Merge it all together into one csv
import glob

all_files = glob.glob("sentiment_*.csv")
li = []
for filename in all_files:
    dataset = pd.read_csv(filename)
    li.append(dataset)
result = pd.concat(li, axis=0, ignore_index=True)
result.to_parquet("../../data/bronze/sentiment_What_Should_We_Do_To_Make_You_Feel_Better_And_Increase_Your_Overall_Satisfaction.parquet", index=False)
result
# Out:
#                                              document sentiment
# 0   keep the good vibes, the trust and open commun...  positive
# 1                     maintain the good collaboration  positive
# 2   more consideration for the employes, making th...   neutral
# 3   I don't feel that my skills and capacities are...  negative
# 4                               less micro management   neutral
# ..                                                ...       ...
# 95                                               none   neutral
# 96                                               none   neutral
# 97                                               none   neutral
# 98                                               none   neutral
# 99                                               none   neutral
#
# [100 rows x 2 columns]

# %% [markdown]
# #### generating keyphrases

# %%
# replace 'key' and 'endpoint':
azure_textanalytics_key = '2180035c81284813a4d457640c87f017'
azure_textanalytics_endpoint = 'https://westeurope.api.cognitive.microsoft.com/'

import pandas as pd
from azure.core.credentials import AzureKeyCredential
from azure.ai.textanalytics import TextAnalyticsClient
client = TextAnalyticsClient(azure_textanalytics_endpoint, AzureKeyCredential(azure_textanalytics_key))

result = pd.DataFrame()
temp   = []
start  = 0      # index id start (ex: 0)
stop   = 100   # index id stop  (ex: 5000)
step   = 1      # max 5 (ex: 5)
column = "col1" # from dataframe
# https://docs.microsoft.com/en-us/azure/cognitive-services/text-analytics/concepts/data-limits

for i in range(start, stop, step): # 0-5000, 5000-10000, etc... (~10min)
    documents = (df[column].iloc[i:i+step]).tolist()

    keyphrases_response = client.extract_key_phrases(documents)
    print(i, end='\r') # second counter
    for idx, doc in enumerate(keyphrases_response):
        comment = pd.DataFrame()
        comment.loc[idy, "document"] = str(documents[idx])
        comment.loc[idy, "key_phrases"] = str(doc.key_phrases)
    temp.append(comment)

result = pd.concat(temp, axis=0, ignore_index=True)
result.to_csv("key_phrases_"+str(start)+"_"+str(stop)+".csv", index=False)
result
# Out:
# 99
#                                              document  \
# 0   keep the good vibes, the trust and open commun...
# 1                     maintain the good collaboration
# 2   more consideration for the employes, making th...
# 3   I don't feel that my skills and capacities are...
# 4                               less micro management
# ..                                                ...
# 95                                               none
# 96                                               none
# 97                                               none
# 98                                               none
# 99                                               none
#
#                                           key_phrases
# 0       ['trust', 'good vibes', 'open communication']
# 1                              ['good collaboration']
# 2   ['employes', 'partners', 'management decision'...
# 3                ['skills', 'capacities', 'accounts']
# 4                                ['micro management']
# ..                                                ...
# 95                                                 []
# 96                                                 []
# 97                                                 []
# 98                                                 []
# 99                                                 []
#
# [100 rows x 2 columns]

# %%
doc.key_phrases

# %%
# Merge it all together into one csv
import glob

all_files = glob.glob("key_phrases_*.csv")
li = []
for filename in all_files:
    dataset = pd.read_csv(filename)
    li.append(dataset)
result = pd.concat(li, axis=0, ignore_index=True)
result.to_parquet("../../data/bronze/key_phrases_What_Should_We_Do_To_Make_You_Feel_Better_And_Increase_Your_Overall_Satisfaction.parquet", index=False)
result
# Out:
#                                              document  \
# 0   keep the good vibes, the trust and open commun...
# 1                     maintain the good collaboration
# 2   more consideration for the employes, making th...
# 3   I don't feel that my skills and capacities are...
# 4                               less micro management
# ..                                                ...
# 95                                               none
# 96                                               none
# 97                                               none
# 98                                               none
# 99                                               none
#
#                                           key_phrases
# 0       ['trust', 'good vibes', 'open communication']
# 1                              ['good collaboration']
# 2   ['employes', 'partners', 'management decision'...
# 3                ['skills', 'capacities', 'accounts']
# 4                                ['micro management']
# ..                                                ...
# 95                                                 []
# 96                                                 []
# 97                                                 []
# 98                                                 []
# 99                                                 []
#
# [100 rows x 2 columns]

# %%
# we now have saved all the files we need
# !ls -al ../../data/bronze/
# Out:
# total 76
# drwxr-xr-x 3 ubuntu root   4096 Feb  6 18:49 .
# drwxr-xr-x 9 ubuntu root   4096 Feb  5 15:14 ..
# drwxrwxr-x 2 ubuntu ubuntu 4096 Feb  5 23:37 .ipynb_checkpoints
# -rw-rw-r-- 1 ubuntu ubuntu 6571 Feb  6 18:38 entities_Any_Additional_Suggestion_To_Improve.parquet
# -rw-rw-r-- 1 ubuntu ubuntu 6744 Feb  6 18:44 entities_What_Felt_Best_During_This_Last_Month.parquet
# -rw-rw-r-- 1 ubuntu ubuntu 7667 Feb  6 18:47 entities_What_Should_We_Do_To_Make_You_Feel_Better_And_Increase_Your_Overall_Satisfaction.parquet
# -rw-rw-r-- 1 ubuntu ubuntu 3172 Feb  6 18:41 key_phrases_Any_Additional_Suggestion_To_Improve.parquet
# -rw-rw-r-- 1 ubuntu ubuntu 3517 Feb  6 18:45 key_phrases_What_Felt_Best_During_This_Last_Month.parquet
# -rw-rw-r-- 1 ubuntu ubuntu 5111 Feb  6 18:48 key_phrases_What_Should_We_Do_To_Make_You_Feel_Better_And_Increase_Your_Overall_Satisfaction.parquet
# -rw-rw-r-- 1 ubuntu ubuntu 9189 Feb  6 18:19 sdworxHRhackathon2021.csv
# -rw-rw-r-- 1 ubuntu ubuntu 2821 Feb  6 18:41 sentiment_Any_Additional_Suggestion_To_Improve.parquet
# -rw-rw-r-- 1 ubuntu ubuntu 2993 Feb  6 18:45 sentiment_What_Felt_Best_During_This_Last_Month.parquet
# -rw-rw-r-- 1 ubuntu ubuntu 4057 Feb  6 18:47 sentiment_What_Should_We_Do_To_Make_You_Feel_Better_And_Increase_Your_Overall_Satisfaction.parquet
